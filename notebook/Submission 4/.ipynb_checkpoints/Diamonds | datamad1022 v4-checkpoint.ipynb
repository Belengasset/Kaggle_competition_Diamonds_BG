# %% [markdown]
# ## Diamonds | datamad1022

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as p
from scipy.stats import norm
from scipy.stats import uniform
from scipy.stats import expon
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

pd.options.display.max_columns = None

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
import pickle

# %%
df = pd.read_csv("../../data/train.csv", sep=',', encoding='UTF-8')

# %%
df
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68
# 1          1   1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04
# 2          2   0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54
# 3          3   1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12
# 4          4   0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450  40450   0.42    Premium     D     SI2   62.1   59.0  4.78  4.82  2.98
# 40451  40451   0.53    Premium     G     VS2   62.0   58.0  5.21  5.18  3.22
# 40452  40452   0.80       Good     G     SI2   62.8   58.0  5.86  5.90  3.69
# 40453  40453   1.01  Very Good     F     VS2   61.5   57.0  6.40  6.48  3.96
# 40454  40454   1.30    Premium     I     VS2   60.1   58.0  7.10  7.14  4.28
#
#        price
# 0      6.353
# 1      9.183
# 2      7.983
# 3      8.371
# 4      6.588
# ...      ...
# 40450  6.551
# 40451  7.382
# 40452  7.768
# 40453  8.726
# 40454  8.771
#
# [40455 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40455 non-null  int64
#  1   carat    40455 non-null  float64
#  2   cut      40455 non-null  object
#  3   color    40455 non-null  object
#  4   clarity  40455 non-null  object
#  5   depth    40455 non-null  float64
#  6   table    40455 non-null  float64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
#  10  price    40455 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 3.4+ MB

# %% [markdown]
# Vemos si hay nulos en el data set:

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
## No hay nulos

# %% [markdown]
# Vemos si hay duplicados en el data set:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
## No hay duplicados

# %% [markdown]
# ## Variable respuesta

# %%
# vamos a ver visualmente como está distribuida la variable respuesta

sns.distplot(
    df.price, 
    hist = False, 
    color = "blue", 
    kde_kws = {"shade": True, "linewidth": 1});

# %% [markdown]
# ## Variables predictoras

# %% [markdown]
# ### Variables numéricas

# %%
# exploramos cuáles son los principales estadísticos de las variables numéricas

df.select_dtypes(include = np.number).describe().T
# Out:
#          count          mean           std     min        25%       50%  \
# id     40455.0  20227.000000  11678.496907   0.000  10113.500  20227.00
# carat  40455.0      0.797576      0.475939   0.200      0.400      0.70
# depth  40455.0     61.746377      1.436796  43.000     61.000     61.80
# table  40455.0     57.451694      2.234569  44.000     56.000     57.00
# x      40455.0      5.729163      1.125244   0.000      4.710      5.69
# y      40455.0      5.732896      1.154799   0.000      4.720      5.70
# z      40455.0      3.537351      0.711002   0.000      2.910      3.52
# price  40455.0      7.783822      1.016828   5.787      6.851      7.78
#
#              75%        max
# id     30340.500  40454.000
# carat      1.040      5.010
# depth     62.500     79.000
# table     59.000     95.000
# x          6.540     10.740
# y          6.540     58.900
# z          4.030     31.800
# price      8.581      9.842

# %%
# Distribution chart for each numerical variable
# ==============================================================================

fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (30, 10))
#sharey

lista_colores = ["blue", "green", "red", "cyan", "magenta", "orange"]

axes = axes.flat

columnas_numeric = df.select_dtypes(include=np.number).columns.difference(["price", "id"])

for i, colum in enumerate(columnas_numeric): 
    sns.histplot(
        data = df,
        x = colum,
        kde = True, 
        color = lista_colores[i], 
        line_kws = {"linewidth": 2}, 
        alpha = 0.2, 
        ax = axes[i])
    
    
    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")
    

fig.tight_layout();

# %%
# Gráfico de relación entre variables predictoras y la variable a predecir
# ==============================================================================


fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (30, 10))

lista_colores = ["blue", "green", "red", "cyan", "magenta", "orange"]

axes = axes.flat

columnas_numeric = df.select_dtypes(include=np.number).columns.difference(["price", "id"])

for i, colum in enumerate(columnas_numeric):
    sns.regplot(
        x = df[colum], 
        y = df["price"], 
        color = "gray", 
        marker = ".", 
        scatter_kws = {"alpha": 0.4}, 
        line_kws = {"color": "red", "alpha": 0.7 }, 
        ax = axes[i])
    
    axes[i].set_title(f"Precio vs {colum}", fontsize = 10, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")
    
fig.tight_layout();

# %% [markdown]
# ### Correlación entre variables numéricas

# %%
sns.heatmap(df.corr(), 
           cmap = "YlGnBu", 
           annot = True);

# %% [markdown]
# We see that there are certain variables of the df that have a very high correlation, these are carat, x, y & z. The variables , y, z are variables that are already indirectly found in the depth variable --> total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79), so we are going to eliminate them from our df to make the prediction.

# %%
df.drop(['x', 'y', 'z'], axis=1, inplace=True)

# %%
sns.heatmap(df.corr(), 
           cmap = "YlGnBu", 
           annot = True);

# %%
sns.pairplot(data= df)

# %% [markdown]
# ### Qualitative variable

# %%
# Chart for each qualitative variable
# ==============================================================================

fig, axes = plt.subplots(1, 3, figsize = (9,5))

axes = axes.flat

columnas_object = df.select_dtypes(include = "object").columns

for i, colum in enumerate(columnas_object):
    df[colum].value_counts().plot.barh(ax = axes[i])
    axes[i].set_title(colum, fontsize = 12, fontweight = "bold")
    axes[i].tick_params(labelsize = 10)
    axes[i].set_xlabel("")
    
fig.tight_layout();

# %% [markdown]
# ## Management of outliers

# %%
df_numericas = df.select_dtypes(include=np.number)

# %%
df_numericas.head(2)
# Out:
#    id  carat  depth  table  price
# 0   0   0.30   62.4   58.0  6.353
# 1   1   1.01   62.7   56.0  9.183

# %%
fig, ax = plt.subplots(5, 1, figsize=(20,15))

for i in range(len(df_numericas.columns)):
    sns.boxplot(x=df_numericas.columns[i], data=df_numericas, ax=ax[i])
plt.show()

# %% [markdown]
# Function to detect the outliers:

# %%
def detectar_outliers(lista_columnas, dataframe): 
    
    dicc_indices = {} 
    
    for col in lista_columnas:
        
        Q1 = np.nanpercentile(dataframe[col], 25)
        Q3 = np.nanpercentile(dataframe[col], 75)
        
        IQR = Q3 - Q1
        
        outlier_step = 1.5 * IQR
        
        outliers_data = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)]
        
        
        if outliers_data.shape[0] > 0: 
        
            dicc_indices[col] = (list(outliers_data.index))

    
    return dicc_indices

# %%
lista_columnas = df_numericas.columns
lista_columnas
# Out:
# Index(['id', 'carat', 'depth', 'table', 'price'], dtype='object')

# %%
# we apply the function and extract the outliers indexes.

ind = detectar_outliers(lista_columnas, df)

# %% [markdown]
# We are going to delete the outliers:

# %%
valores = list(ind.values())
valores = [indice for sublista in valores for indice in sublista]
df.shape
# Out:
# (40455, 8)

# %%
final = df_numericas.drop(df_numericas.index[list(valores)] )
final.shape
# Out:
# (36974, 5)

# %%
fig, ax = plt.subplots(5, 1, figsize=(20,15))

for i in range(len(final.columns)):
    sns.boxplot(x=final.columns[i], data=final, ax=ax[i])
plt.show()

# %%
df_clean = final.merge(df[['id', 'cut', 'color', 'clarity']], on='id', how='left')

# %%
df_clean.head()
# Out:
#    id  carat  depth  table  price        cut color clarity
# 0   0   0.30   62.4   58.0  6.353    Premium     D     SI2
# 1   1   1.01   62.7   56.0  9.183      Ideal     E    VVS2
# 2   2   0.72   61.8   59.0  7.983      Ideal     F     VS2
# 3   3   1.08   63.2   57.0  8.371  Very Good     G     SI2
# 4   4   0.36   62.3   59.0  6.588    Premium     G     VS1

# %%
df_clean.to_csv("df_sin_outliers.csv")

# %% [markdown]
# # What is the distribution of our data?

# %%
columnas = final.columns
columnas
# Out:
# Index(['id', 'carat', 'depth', 'table', 'price'], dtype='object')

# %%
columnas = final.columns.drop('id') 

fig, ax = plt.subplots(1,4, figsize = (20,7))
ax = ax.flat

for i, columna in enumerate(columnas):
    sns.histplot(data=final, x=columna, kde=True, ax=ax[i])

fig.delaxes(ax[-1])
plt.show()

# %%
stats.shapiro(final["price"])
# Out:
# ShapiroResult(statistic=0.9608796834945679, pvalue=0.0)

# %% [markdown]
# In the case of ShapiroResult(statistic=0.9629329442977905, pvalue=0.0), the p-value is zero, which means that there is significant evidence to reject the null hypothesis that the data follow a normal distribution. Therefore, it is concluded that the data do not follow a normal distribution.

# %% [markdown]
# ## STANDARDIZATION

# %% [markdown]
# Now we have to standardize the numerical variables:

# %%
df_clean.select_dtypes(include=np.number).columns.drop('id')
# Out:
# Index(['carat', 'depth', 'table', 'price'], dtype='object')

# %%
scaler=StandardScaler()

# %%
scaler.fit(df_clean[['carat', 'depth', 'table']])
X_escaladas = scaler.transform(df_clean[['carat', 'depth', 'table']])
df_clean[['carat', 'depth', 'table']] = X_escaladas
df_clean.head()
# Out:
#    id     carat     depth     table  price        cut color clarity
# 0   0 -1.093044  0.556542  0.363900  6.353    Premium     D     SI2
# 1   1  0.676108  0.827038 -0.626538  9.183      Ideal     E    VVS2
# 2   2 -0.046503  0.015549  0.859120  7.983      Ideal     F     VS2
# 3   3  0.850531  1.277866 -0.131319  8.371  Very Good     G     SI2
# 4   4 -0.943538  0.466376  0.859120  6.588    Premium     G     VS1

# %%
# save in a pickle

import pickle

with open('estandarizacion.pkl', 'wb') as s:
    pickle.dump(scaler, s)

# %% [markdown]
# ## ENCODING

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder  
from sklearn.preprocessing import OrdinalEncoder

# %%
columnas_object = df_clean.select_dtypes(include="object")
columnas_object.head()
# Out:
#          cut color clarity
# 0    Premium     D     SI2
# 1      Ideal     E    VVS2
# 2      Ideal     F     VS2
# 3  Very Good     G     SI2
# 4    Premium     G     VS1

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,5))

for i, columna in enumerate(["color", "cut", "clarity"]):
    df_relacion_cat = df.groupby(columna)["price"].mean().reset_index()
    sns.barplot(data=df_relacion_cat, x=columna, y="price", ax=axs[i])
    axs[i].set_title(columna)

plt.show()

# %% [markdown]
# We use the ordinal enconder to specify the categorical variables that do have a specific order:

# %%
def ordinal_encoder1(df, columna, orden_valores):
    
     
    ordinal = OrdinalEncoder(categories = [orden_valores], dtype = int)

    transformados_oe = ordinal.fit_transform(df[[columna]])
    
    
    oe_df = pd.DataFrame(transformados_oe)
    
    oe_df.columns = ordinal.feature_names_in_

    columna += "_oe"
    
    df[columna] = oe_df
     
    return df

# %%
orden_color = [ "E", "D" , "F", "G", "H", "I", "J"]

# %%
df_encoded = df_clean.copy()
df_encoded = ordinal_encoder1(df_encoded,"color", orden_color)
df_encoded.head()
# Out:
#    id     carat     depth     table  price        cut color clarity  color_oe
# 0   0 -1.093044  0.556542  0.363900  6.353    Premium     D     SI2         1
# 1   1  0.676108  0.827038 -0.626538  9.183      Ideal     E    VVS2         0
# 2   2 -0.046503  0.015549  0.859120  7.983      Ideal     F     VS2         2
# 3   3  0.850531  1.277866 -0.131319  8.371  Very Good     G     SI2         3
# 4   4 -0.943538  0.466376  0.859120  6.588    Premium     G     VS1         3

# %%
orden_cut = [ "Ideal", "Good", "Very Good", "Premium", "Fair"]

# %%
df_encoded = ordinal_encoder1(df_encoded,"cut", orden_cut)
df_encoded.head()
# Out:
#    id     carat     depth     table  price        cut color clarity  color_oe  \
# 0   0 -1.093044  0.556542  0.363900  6.353    Premium     D     SI2         1
# 1   1  0.676108  0.827038 -0.626538  9.183      Ideal     E    VVS2         0
# 2   2 -0.046503  0.015549  0.859120  7.983      Ideal     F     VS2         2
# 3   3  0.850531  1.277866 -0.131319  8.371  Very Good     G     SI2         3
# 4   4 -0.943538  0.466376  0.859120  6.588    Premium     G     VS1         3
#
#    cut_oe
# 0       3
# 1       0
# 2       0
# 3       2
# 4       3

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'VVS2', 'VS2', 'VS1', 'SI1', 'VVS1', 'IF', 'I1'],
#       dtype=object)

# %%
orden_clarity = [ "VVS1", "IF", "VVS2", "VS1", "VS2", "SI1", "I1", "SI2"]

# %%
df_encoded = ordinal_encoder1(df_encoded,"clarity", orden_clarity)
df_encoded.head()
# Out:
#    id     carat     depth     table  price        cut color clarity  color_oe  \
# 0   0 -1.093044  0.556542  0.363900  6.353    Premium     D     SI2         1
# 1   1  0.676108  0.827038 -0.626538  9.183      Ideal     E    VVS2         0
# 2   2 -0.046503  0.015549  0.859120  7.983      Ideal     F     VS2         2
# 3   3  0.850531  1.277866 -0.131319  8.371  Very Good     G     SI2         3
# 4   4 -0.943538  0.466376  0.859120  6.588    Premium     G     VS1         3
#
#    cut_oe  clarity_oe
# 0       3           7
# 1       0           2
# 2       0           4
# 3       2           7
# 4       3           3

# %%
df_encoded.drop(['cut', 'color', 'clarity'], axis=1, inplace=True)
df_encoded.head()
# Out:
#    id     carat     depth     table  price  color_oe  cut_oe  clarity_oe
# 0   0 -1.093044  0.556542  0.363900  6.353         1       3           7
# 1   1  0.676108  0.827038 -0.626538  9.183         0       0           2
# 2   2 -0.046503  0.015549  0.859120  7.983         2       0           4
# 3   3  0.850531  1.277866 -0.131319  8.371         3       2           7
# 4   4 -0.943538  0.466376  0.859120  6.588         3       3           3

# %% [markdown]
# Test encoding:

# %%
df_test = pd.read_csv("../../data/test.csv", sep=',', encoding='UTF-8')
df_test.head()
# Out:
#    id  carat      cut color clarity  depth  table     x     y     z
# 0   0   0.32    Ideal     I     SI1   60.5   58.0  4.43  4.49  2.70
# 1   1   1.24  Premium     I     SI1   62.9   60.0  6.80  6.74  4.26
# 2   2   1.66  Premium     D     SI1   62.0   59.0  7.55  7.60  4.70
# 3   3   0.75  Premium     D     SI2   60.6   56.0  5.94  5.90  3.59
# 4   4   1.50     Fair     E     SI2   64.8   55.0  7.26  7.15  4.67

# %%
df_test.drop(['x', 'y', 'z'], axis=1, inplace=True)

# %%
df_test.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table'], dtype='object')

# %%
df_test = ordinal_encoder1(df_test,"color", orden_color)
df_test = ordinal_encoder1(df_test,"cut", orden_cut)
df_test = ordinal_encoder1(df_test,"clarity", orden_clarity)

# %%
df_test.head()
# Out:
#    id  carat      cut color clarity  depth  table  color_oe  cut_oe  \
# 0   0   0.32    Ideal     I     SI1   60.5   58.0         5       0
# 1   1   1.24  Premium     I     SI1   62.9   60.0         5       3
# 2   2   1.66  Premium     D     SI1   62.0   59.0         1       3
# 3   3   0.75  Premium     D     SI2   60.6   56.0         1       3
# 4   4   1.50     Fair     E     SI2   64.8   55.0         0       4
#
#    clarity_oe
# 0           5
# 1           5
# 2           5
# 3           7
# 4           7

# %%
df_test.drop(['cut', 'color', 'clarity'], axis=1, inplace=True)
df_test.head()
# Out:
#    id  carat  depth  table  color_oe  cut_oe  clarity_oe
# 0   0   0.32   60.5   58.0         5       0           5
# 1   1   1.24   62.9   60.0         5       3           5
# 2   2   1.66   62.0   59.0         1       3           5
# 3   3   0.75   60.6   56.0         1       3           7
# 4   4   1.50   64.8   55.0         0       4           7

# %%
df_test.shape
# Out:
# (13485, 7)

# %%
df_test.to_csv('df_test.csv', index=False)

# %% [markdown]
# ### Separation test-train

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics

# %%
X = df_encoded.drop('price', axis =1)
y = df_encoded['price']


X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

# %%
X_train
# Out:
#           id     carat     depth     table  color_oe  cut_oe  clarity_oe
# 24418  26728  2.395425 -0.254948 -1.121757         4       0           3
# 29668  32466  0.750861  0.195880 -0.131319         5       3           7
# 24526  26851 -1.093044  1.638527 -1.616976         1       1           4
# 2616    2845  0.402014  0.736873  0.363900         4       3           5
# 4525    4934 -1.093044  1.187700  0.859120         3       1           3
# ...      ...       ...       ...       ...       ...     ...         ...
# 16850  18434  1.971825 -0.976272  1.354339         1       3           7
# 6265    6852 -0.046503  0.556542 -0.626538         2       0           3
# 11284  12358 -0.694362 -1.787761  1.156251         0       2           4
# 860      926 -0.495021 -0.435279 -0.626538         0       3           3
# 15795  17277 -0.993374 -0.886106  1.354339         1       3           7
#
# [29579 rows x 7 columns]

# %%
print(y_train.describe())
# Out:
# count    29579.000000
# mean         7.703545
# std          0.981044
# min          5.814000
# 25%          6.802000
# 50%          7.691000
# 75%          8.511000
# max          9.842000
# Name: price, dtype: float64

# %%
print(y_test.describe())
# Out:
# count    7395.000000
# mean        7.701444
# std         0.968785
# min         5.787000
# 25%         6.821000
# 50%         7.697000
# 75%         8.490000
# max         9.822000
# Name: price, dtype: float64

# %% [markdown]
# ## Adjustment of the model

# %% [markdown]
# ### DECISION TREE

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# ajustamos el modelo
max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 2.6457513110645907

# %%
print(regressor.tree_.max_depth)
# Out:
# 37

# %%
# hacemos las predicciones sobre los dos set de datos el X_test y el X_train
y_pred_test_dt = regressor.predict(X_test)
y_pred_train_dt = regressor.predict(X_train)

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    
    
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
# overfitting?

dt_results1 = metricas(y_test, y_train, y_pred_test_dt, y_pred_train_dt, "Decission Tree I")
dt_results1
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  1.011045e-01  1.969520e-02  1.403396e-01  0.979012   test  Decission Tree I
# 1  7.596915e-18  6.747416e-33  8.214265e-17  1.000000  train  Decission Tree I

# %%
param = {"max_depth": [4, 6, 8, 10, 12, 14, 16, 18],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=0,
            n_jobs = -1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [4, 6, 8, 10, 12, 14, 16, 18],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
# best_estimator_
best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=14, max_features=6, min_samples_split=50)

# %%
y_pred_test_dt2 = best_tree.predict(X_test)
y_pred_train_dt2 = best_tree.predict(X_train)

# %%
dt_results2 = metricas(y_test, y_train, y_pred_test_dt2, y_pred_train_dt2, "Decision tree II")
dt_results2
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.085590  0.012811  0.113185  0.986348   test  Decision tree II
# 1  0.075263  0.009590  0.097928  0.990036  train  Decision tree II

# %%
df_all = pd.concat([dt_results1, dt_results2], axis = 0)
df_all
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  1.011045e-01  1.969520e-02  1.403396e-01  0.979012   test  Decission Tree I
# 1  7.596915e-18  6.747416e-33  8.214265e-17  1.000000  train  Decission Tree I
# 0  8.559042e-02  1.281095e-02  1.131855e-01  0.986348   test  Decision tree II
# 1  7.526343e-02  9.589896e-03  9.792801e-02  0.990036  train  Decision tree II

# %%
with open('mejor_modeloDTII.pkl', 'wb') as modelo:
        pickle.dump(gs, modelo)

# %% [markdown]
# ## Random Forest

# %%
param = {"max_depth": [4, 6, 8, 10, 12, 14, 16, 18],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

bosque = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            verbose=0,
            n_jobs = -1,
            return_train_score = True,
            scoring="neg_mean_squared_error")
bosque.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [4, 6, 8, 10, 12, 14, 16, 18],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
bos = bosque.best_estimator_
bos
# Out:
# RandomForestRegressor(max_depth=14, max_features=5, min_samples_split=10)

# %% [markdown]
# ### Prediction

# %%
y_pred_test_rf = bos.predict(X_test)
y_pred_train_rf = bos.predict(X_train)

# %%
rf_results = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest")
rf_results
# Out:
#         MAE       MSE      RMSE        R2    set         modelo
# 0  0.077632  0.010362  0.101792  0.988958   test  Random Forest
# 1  0.058180  0.005761  0.075901  0.994014  train  Random Forest

# %%
df_all = pd.concat([df_all, rf_results ], axis = 0)
df_all
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  1.011045e-01  1.969520e-02  1.403396e-01  0.979012   test  Decission Tree I
# 1  7.596915e-18  6.747416e-33  8.214265e-17  1.000000  train  Decission Tree I
# 0  8.559042e-02  1.281095e-02  1.131855e-01  0.986348   test  Decision tree II
# 1  7.526343e-02  9.589896e-03  9.792801e-02  0.990036  train  Decision tree II
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test     Random Forest
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train     Random Forest

# %%
with open('mejor_modeloBos.pkl', 'wb') as modelo:
        pickle.dump(bos, modelo)

# %% [markdown]
# ## KNeighborsRegressor

# %%
knn_scores = []

for k in range(1,21):
    
    score=cross_val_score(KNeighborsRegressor(n_neighbors = k),
                          X = X,
                          y = y,
                          cv=10, 
                         scoring = "neg_mean_squared_error")
    knn_scores.append(score.mean())

# %%
knn = pd.DataFrame(knn_scores, range(1,21)).reset_index()
knn.columns = ["number_neighbors", "score"]
knn.sort_values(by = "score", ascending = False).head(3)
# Out:
#     number_neighbors     score
# 19                20 -1.010629
# 16                17 -1.013029
# 14                15 -1.018415

# %%
knn = KNeighborsRegressor(n_neighbors =2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
y_pred_knn_test = knn.predict(X_test)
y_pred_knn_train = knn.predict(X_train)

# %%
results_knn = metricas(y_test, y_train, y_pred_knn_test, y_pred_knn_train, "KNN")
df_all = pd.concat([df_all, results_knn ], axis = 0)
df_all
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  1.011045e-01  1.969520e-02  1.403396e-01  0.979012   test  Decission Tree I
# 1  7.596915e-18  6.747416e-33  8.214265e-17  1.000000  train  Decission Tree I
# 0  8.559042e-02  1.281095e-02  1.131855e-01  0.986348   test  Decision tree II
# 1  7.526343e-02  9.589896e-03  9.792801e-02  0.990036  train  Decision tree II
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test     Random Forest
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train     Random Forest
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test               KNN
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train               KNN

# %%
with open('mejor_modeloKNN.pkl', 'wb') as modelo:
        pickle.dump(knn, modelo)

# %% [markdown]
# ## Gradient Boosting

# %%
param = {"max_depth": [2,3, 4,6,8],
         "min_samples_split": [50, 100, 150, 200, 250],
         "max_features": [1,2,3,4], 
         "min_samples_leaf": [100, 150, 200, 250]}

grid = GridSearchCV(
        estimator  = GradientBoostingRegressor(),
        param_grid = param,
        cv=10,
        verbose=0,
        n_jobs = -1,
        return_train_score = True,
        scoring="neg_mean_squared_error")
       

grid.fit(X = X_train, y = y_train)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4, 6, 8],
#                          'max_features': [1, 2, 3, 4],
#                          'min_samples_leaf': [100, 150, 200, 250],
#                          'min_samples_split': [50, 100, 150, 200, 250]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'max_depth': 8,
#  'max_features': 4,
#  'min_samples_leaf': 100,
#  'min_samples_split': 200}

# %%
y_pred_gb_test= grid.predict(X_test)
y_pred_gb_train= grid.predict(X_train)

# %%
results_gradient = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient")
df_all = pd.concat([df_all, results_gradient ], axis = 0)
df_all
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  1.011045e-01  1.969520e-02  1.403396e-01  0.979012   test  Decission Tree I
# 1  7.596915e-18  6.747416e-33  8.214265e-17  1.000000  train  Decission Tree I
# 0  8.559042e-02  1.281095e-02  1.131855e-01  0.986348   test  Decision tree II
# 1  7.526343e-02  9.589896e-03  9.792801e-02  0.990036  train  Decision tree II
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test     Random Forest
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train     Random Forest
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test               KNN
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train               KNN
# 0  7.763238e-02  1.036170e-02  1.017924e-01  0.988958   test          Gradient
# 1  5.817970e-02  5.760937e-03  7.590084e-02  0.994014  train          Gradient

# %%
with open('mejor_modeloGB.pkl', 'wb') as modelo:
        pickle.dump(grid, modelo)
